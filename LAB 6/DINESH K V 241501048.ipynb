# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# EXPERIMENT 1

# %%
import numpy as np

def gradient_descent(x, y, lr=0.05, epochs=100):
    m, c = 2, 0
    n = len(x)

    for _ in range(epochs):
        y_pred = m * x + c
        dm = (-2/n) * sum(x * (y - y_pred))
        dc = (-2/n) * sum(y - y_pred)
        m -= lr * dm
        c -= lr * dc

    return m, c  # moved outside the loop

x = np.array([1,2,3,4,5])
y = np.array([2,4,6,8,10])

m, c = gradient_descent(x, y)
print('Slope:', m, 'Intercept:', c)
# Out:
# Slope: 2.0 Intercept: 0.0

# %% [markdown]
# EXPERIMENT 2

# %%
import numpy as np

def gradient_descent(x, y, lr=0.01, epochs=100):
    m, c = 0, 0
    n = len(x)
    for _ in range(epochs):
        y_pred = m * x + c
        dm = (-2/n) * sum(x * (y - y_pred))
        dc = (-2/n) * sum(y - y_pred)
        m -= lr * dm
        c -= lr * dc
    return m, c

x = np.array([1,2,3,4,5])
y = np.array([3,6,9,12,15])

m, c = gradient_descent(x, y)
print("Slope:", m, "Intercept:", c)
# Out:
# Slope: 2.8476489033443033 Intercept: 0.5500357996478975

# %% [markdown]
# EXPERIMENT 3

# %%
import numpy as np

def gradient_descent(x, y, lr=0.01, epochs=100):
    m, c = 0, 0
    n = len(x)
    for _ in range(epochs):
        y_pred = m * x + c
        dm = (-2/n) * sum(x * (y - y_pred))
        dc = (-2/n) * sum(y - y_pred)
        m -= lr * dm
        c -= lr * dc
    return m, c

x = np.array([1,2,3,4,5])
y = np.array([6,7,8,9,10])

m, c = gradient_descent(x, y)
print("Slope:", m, "Intercept:", c)
# Out:
# Slope: 1.8659426338612635 Intercept: 1.8736723296348194

# %% [markdown]
# EXPERIMENT 4

# %%
import numpy as np

def gradient_descent(x, y, lr=0.01, epochs=100):
    m, c = 0, 0
    n = len(x)
    for _ in range(epochs):
        y_pred = m * x + c
        dm = (-2/n) * sum(x * (y - y_pred))
        dc = (-2/n) * sum(y - y_pred)
        m -= lr * dm
        c -= lr * dc
    return m, c

x = np.array([1,2,3,4,5])
y = np.array([2,6,10,14,18])

m, c = gradient_descent(x, y)
print("Slope:", m, "Intercept:", c)
# Out:
# Slope: 3.430174671360473 Intercept: 0.05725024096298772

# %% [markdown]
# EXPERIMENT 5

# %%
import numpy as np

def gradient_descent(x, y, lr=0.01, epochs=100):
    m, c = 0, 0
    n = len(x)
    for _ in range(epochs):
        y_pred = m * x + c
        dm = (-2/n) * sum(x * (y - y_pred))
        dc = (-2/n) * sum(y - y_pred)
        m -= lr * dm
        c -= lr * dc
    return m, c

x = np.array([1,2,3,4,5])
y = np.array([2.2,3.9,6.1,7.8,10.2])

m, c = gradient_descent(x, y)
print("Slope:", m, "Intercept:", c)
# Out:
# Slope: 1.9017746078768385 Intercept: 0.38852165931630256

# %% [markdown]
# EXPERIMENT 6

# %%
import numpy as np

def gradient_descent(x, y, lr=0.001, epochs=100):
    m, c = 0, 0
    n = len(x)
    for _ in range(epochs):
        y_pred = m * x + c
        dm = (-2/n) * sum(x * (y - y_pred))
        dc = (-2/n) * sum(y - y_pred)
        m -= lr * dm
        c -= lr * dc
    return m, c

x = np.array([1,2,3,4,5])
y = np.array([2,4,6,8,10])

m, c = gradient_descent(x, y)
print("Slope:", m, "Intercept:", c)
# Out:
# Slope: 1.6928167263549765 Intercept: 0.4504636608703611

# %% [markdown]
# EXPERIMENT 7

# %%
import numpy as np

def gradient_descent(x, y, lr=0.1, epochs=100):
    m, c = 0, 0
    n = len(x)
    for _ in range(epochs):
        y_pred = m * x + c
        dm = (-2/n) * sum(x * (y - y_pred))
        dc = (-2/n) * sum(y - y_pred)
        m -= lr * dm
        c -= lr * dc
    return m, c

x = np.array([1,2,3,4,5])
y = np.array([2,4,6,8,10])

m, c = gradient_descent(x, y)
print("Slope:", m, "Intercept:", c)
# Out:
# Slope: -66076864889283.2 Intercept: -18302232028396.133

# %% [markdown]
# EXPERIMRNT 8

# %%
import numpy as np

def gradient_descent(x, y, lr=0.01, epochs=1000):
    m, c = 0, 0
    n = len(x)
    for _ in range(epochs):
        y_pred = m * x + c
        dm = (-2/n) * sum(x * (y - y_pred))
        dc = (-2/n) * sum(y - y_pred)
        m -= lr * dm
        c -= lr * dc
    return m, c

x = np.array([1,2,3,4,5])
y = np.array([2,4,6,8,10])

m, c = gradient_descent(x, y)
print("Slope:", m, "Intercept:", c)
# Out:
# Slope: 1.9951803506719779 Intercept: 0.017400463340610635

# %% [markdown]
# EXPERIMENT 9

# %%
import numpy as np

def gradient_descent(x, y, lr=0.01, epochs=100):
    m, c = 0, 0
    n = len(x)
    for _ in range(epochs):
        y_pred = m * x + c
        dm = (-2/n) * sum(x * (y - y_pred))
        dc = (-2/n) * sum(y - y_pred)
        m -= lr * dm
        c -= lr * dc
    return m, c

x = np.array([1,2,3,4,5])
y = np.array([-2,-4,-6,-8,-10])

m, c = gradient_descent(x, y)
print("Slope:", m, "Intercept:", c)
# Out:
# Slope: -1.8984326022295357 Intercept: -0.36669053309859806

# %% [markdown]
# EXPERIMENT 10

# %%
import numpy as np

def gradient_descent(x, y, lr=0.01, epochs=100):
    m, c = 0, 0
    n = len(x)
    for _ in range(epochs):
        y_pred = m * x + c
        dm = (-2/n) * sum(x * (y - y_pred))
        dc = (-2/n) * sum(y - y_pred)
        m -= lr * dm
        c -= lr * dc
    return m, c

x = np.array([1,2,3,4,5])
y = np.array([5,5,5,5,5])

m, c = gradient_descent(x, y)
print("Slope:", m, "Intercept:", c)
# Out:
# Slope: 0.9167263327464955 Intercept: 1.6903270630855207
