# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# EXPERIMENT 1

# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
cost_matrix = np.array([[9, 2, 7, 8],
[6, 4, 3, 7],
[5, 8, 1, 8],
[7, 6, 9, 4]])
row_ind, col_ind = linear_sum_assignment(cost_matrix)
min_cost = cost_matrix[row_ind, col_ind].sum()
print("Optimal Assignments:", list(zip(row_ind, col_ind)))
print("Minimum Assignment Cost:", min_cost)
# Out:
# Optimal Assignments: [(np.int64(0), np.int64(1)), (np.int64(1), np.int64(0)), (np.int64(2), np.int64(2)), (np.int64(3), np.int64(3))]
# Minimum Assignment Cost: 13

# %% [markdown]
# EXPERIMENT 2

# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
cost_matrix = np.array([
[8, 2, 5],
[7, 4, 6],
[3, 9, 1]])
row_ind, col_ind = linear_sum_assignment(cost_matrix)
min_cost = cost_matrix[row_ind, col_ind].sum()
print("Optimal Assignments:", list(zip(row_ind, col_ind)))
print("Minimum Assignment Cost:", min_cost)
# Out:
# Optimal Assignments: [(np.int64(0), np.int64(1)), (np.int64(1), np.int64(0)), (np.int64(2), np.int64(2))]
# Minimum Assignment Cost: 10

# %% [markdown]
# EXPERIMENT 3

# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
cost_matrix = np.array([
[6, 8, 7],
[5, 3, 9],
[4, 6, 2]])
row_ind, col_ind = linear_sum_assignment(cost_matrix)
min_cost = cost_matrix[row_ind, col_ind].sum()
print("Optimal Assignments:", list(zip(row_ind, col_ind)))
print("Minimum Assignment Cost:", min_cost)
# Out:
# Optimal Assignments: [(np.int64(0), np.int64(0)), (np.int64(1), np.int64(1)), (np.int64(2), np.int64(2))]
# Minimum Assignment Cost: 11

# %% [markdown]
# EXPERIMENT 4

# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
cost_matrix = np.array([
[9, 2, 7, 8],
[6, 4, 3, 7],
[5, 8, 1, 8],
[7, 6, 9, 4]])
row_ind, col_ind = linear_sum_assignment(cost_matrix)
min_cost = cost_matrix[row_ind, col_ind].sum()
print("Optimal Assignments:", list(zip(row_ind, col_ind)))
print("Minimum Assignment Cost:", min_cost)
# Out:
# Optimal Assignments: [(np.int64(0), np.int64(1)), (np.int64(1), np.int64(0)), (np.int64(2), np.int64(2)), (np.int64(3), np.int64(3))]
# Minimum Assignment Cost: 13

# %% [markdown]
# EXPERIMENT 5

# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
cost_matrix = np.array([
[10, 3, 6, 9],
[5, 8, 7, 6],
[9, 4, 8, 5],
[7, 6, 3, 8]])
row_ind, col_ind = linear_sum_assignment(cost_matrix)
min_cost = cost_matrix[row_ind, col_ind].sum()
print("Optimal Assignments:", list(zip(row_ind, col_ind)))
print("Minimum Assignment Cost:", min_cost)
# Out:
# Optimal Assignments: [(np.int64(0), np.int64(1)), (np.int64(1), np.int64(0)), (np.int64(2), np.int64(3)), (np.int64(3), np.int64(2))]
# Minimum Assignment Cost: 16

# %% [markdown]
# EXPERIMENT 6

# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
cost_matrix = np.array([
[4, 7, 8, 6],
[6, 5, 9, 7],
[8, 6, 4, 5],
[7, 8, 5, 6]])
row_ind, col_ind = linear_sum_assignment(cost_matrix)
min_cost = cost_matrix[row_ind, col_ind].sum()
print("Optimal Assignments:", list(zip(row_ind, col_ind)))
print("Minimum Assignment Cost:", min_cost)
# Out:
# Optimal Assignments: [(np.int64(0), np.int64(0)), (np.int64(1), np.int64(1)), (np.int64(2), np.int64(2)), (np.int64(3), np.int64(3))]
# Minimum Assignment Cost: 19

# %% [markdown]
# EXPERIMENT 7

# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
cost_matrix = np.array([
[9, 11, 14, 11, 7],
[6, 15, 13, 13, 10],
[12, 13, 6, 8, 8],
[11, 9, 10, 12, 9],
[7, 12, 14, 10, 14]])
row_ind, col_ind = linear_sum_assignment(cost_matrix)
min_cost = cost_matrix[row_ind, col_ind].sum()
print("Optimal Assignments:", list(zip(row_ind, col_ind)))
print("Minimum Assignment Cost:", min_cost)
# Out:
# Optimal Assignments: [(np.int64(0), np.int64(4)), (np.int64(1), np.int64(0)), (np.int64(2), np.int64(2)), (np.int64(3), np.int64(1)), (np.int64(4), np.int64(3))]
# Minimum Assignment Cost: 38

# %% [markdown]
# EXPERIMENT 8

# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
cost_matrix = np.array([
[7, 5, 9, 8, 11],
[9, 12, 7, 6, 10],
[8, 5, 6, 9, 7],
[6, 8, 11, 10, 9],
[10, 9, 8, 7, 6]])
row_ind, col_ind = linear_sum_assignment(cost_matrix)
min_cost = cost_matrix[row_ind, col_ind].sum()
print("Optimal Assignments:", list(zip(row_ind, col_ind)))
print("Minimum Assignment Cost:", min_cost)
# Out:
# Optimal Assignments: [(np.int64(0), np.int64(1)), (np.int64(1), np.int64(3)), (np.int64(2), np.int64(2)), (np.int64(3), np.int64(0)), (np.int64(4), np.int64(4))]
# Minimum Assignment Cost: 29

# %% [markdown]
# EXPERIMENT 9

# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
cost_matrix = np.array([
[11, 17, 8, 16],
[9, 7, 12, 6],
[13, 16, 15, 12],
[8, 14, 6, 10]])
row_ind, col_ind = linear_sum_assignment(cost_matrix)
min_cost = cost_matrix[row_ind, col_ind].sum()
print("Optimal Assignments:", list(zip(row_ind, col_ind)))
print("Minimum Assignment Cost:", min_cost)
# Out:
# Optimal Assignments: [(np.int64(0), np.int64(2)), (np.int64(1), np.int64(1)), (np.int64(2), np.int64(3)), (np.int64(3), np.int64(0))]
# Minimum Assignment Cost: 35

# %% [markdown]
# EXPERIMENT 10

# %%
import numpy as np
from scipy.optimize import linear_sum_assignment
cost_matrix = np.array([
[14, 5, 8],
[2, 12, 6],
[7, 8, 3]])
row_ind, col_ind = linear_sum_assignment(cost_matrix)
min_cost = cost_matrix[row_ind, col_ind].sum()
print("Optimal Assignments:", list(zip(row_ind, col_ind)))
print("Minimum Assignment Cost:", min_cost)
# Out:
# Optimal Assignments: [(np.int64(0), np.int64(1)), (np.int64(1), np.int64(0)), (np.int64(2), np.int64(2))]
# Minimum Assignment Cost: 10
