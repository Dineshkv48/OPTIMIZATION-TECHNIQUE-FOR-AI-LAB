# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# EXPERIMENT 1

# %%
import pulp
lp = pulp.LpProblem("LPP1", pulp.LpMaximize)
x = pulp.LpVariable('x', lowBound=0)
y = pulp.LpVariable('y', lowBound=0)
lp += 3*x + 2*y
lp += x + y <= 4
lp += x <= 2
lp += y <= 3
lp.solve()
print("X=",x.value(), "Y=",y.value(), "Z=",pulp.value(lp.objective))
# Out:
# X= 2.0 Y= 2.0 Z= 10.0

# %% [markdown]
# EXPERIMENT 2

# %%
import pulp
lp = pulp.LpProblem("LPP2", pulp.LpMaximize)
x = pulp.LpVariable('x', lowBound=0)
y = pulp.LpVariable('y', lowBound=0)
lp += 5*x + 4*y
lp += 6*x + 4*y <= 24
lp += x + 2*y <= 6
lp.solve()
print("X=",x.value(), "Y=",y.value(), "Z=",pulp.value(lp.objective))
# Out:
# X= 3.0 Y= 1.5 Z= 21.0

# %% [markdown]
# EXPERIMENT 3

# %%
import pulp
lp = pulp.LpProblem("LPP3", pulp.LpMinimize)
x = pulp.LpVariable('x', lowBound=0)
y = pulp.LpVariable('y', lowBound=0)
lp += x + y
lp += 2*x + y >= 6
lp += x + 2*y >= 6
lp.solve()
print("X=",x.value(), "Y=",y.value(), "Z=",pulp.value(lp.objective))
# Out:
# X= 2.0 Y= 2.0 Z= 4.0

# %% [markdown]
# EXPERIMENT 4

# %%
import pulp
lp = pulp.LpProblem("LPP4", pulp.LpMaximize)
x = pulp.LpVariable('x', lowBound=0)
y = pulp.LpVariable('y', lowBound=0)
lp += 4*x + 3*y
lp += 2*x + y <= 8
lp += x + 2*y <= 8
lp.solve()
print("X=",x.value(), "Y=",y.value(), "Z=",pulp.value(lp.objective))
# Out:
# X= 2.6666667 Y= 2.6666667 Z= 18.6666669

# %% [markdown]
# EXPERIMENT 5

# %%
import pulp
lp = pulp.LpProblem("LPP5", pulp.LpMinimize)
x = pulp.LpVariable('x', lowBound=0)
y = pulp.LpVariable('y', lowBound=0)
lp += 3*x + 5*y
lp += x + y >= 4
lp += x <= 3
lp += y <= 3
lp.solve()
print("X=",x.value(), "Y=",y.value(), "Z=",pulp.value(lp.objective))
# Out:
# X= 3.0 Y= 1.0 Z= 14.0

# %% [markdown]
# EXPERIMENT 6

# %%
import pulp
lp = pulp.LpProblem("LPP6", pulp.LpMaximize)
x = pulp.LpVariable('x', lowBound=0)

y = pulp.LpVariable('y', lowBound=0)
lp += 6*x + 5*y
lp += x + y <= 5
lp += 3*x + 2*y <= 12
lp.solve()
print("X=",x.value(), "Y=",y.value(), "Z=",pulp.value(lp.objective))
# Out:
# X= 2.0 Y= 3.0 Z= 27.0

# %% [markdown]
# EXPERIMENT 7

# %%
import pulp
lp = pulp.LpProblem("LPP7", pulp.LpMinimize)
x = pulp.LpVariable('x', lowBound=1)
y = pulp.LpVariable('y', lowBound=1)
lp += 2*x + 3*y
lp += x + y >= 5
lp.solve()
print("X=",x.value(), "Y=",y.value(), "Z=",pulp.value(lp.objective))
# Out:
# X= 4.0 Y= 1.0 Z= 11.0

# %% [markdown]
# EXPERIMENT 8

# %%
import pulp
lp = pulp.LpProblem("LPP8", pulp.LpMaximize)
x = pulp.LpVariable('x', lowBound=0)
y = pulp.LpVariable('y', lowBound=0)
lp += 7*x + 6*y
lp += 2*x + y <= 6
lp += x + 2*y <= 6
lp.solve()
print("X=",x.value(), "Y=",y.value(), "Z=",pulp.value(lp.objective))
# Out:
# X= 2.0 Y= 2.0 Z= 26.0

# %% [markdown]
# EXPERIMENT 9

# %%
import pulp
lp = pulp.LpProblem("LPP9", pulp.LpMinimize)
x = pulp.LpVariable('x', lowBound=2)
y = pulp.LpVariable('y', lowBound=0)

lp += x + 4*y
lp += x + 2*y >= 8
lp.solve()
print("X=",x.value(), "Y=",y.value(), "Z=",pulp.value(lp.objective))
# Out:
# X= 8.0 Y= 0.0 Z= 8.0

# %% [markdown]
# EXPERIMENT 10

# %%
import pulp
lp = pulp.LpProblem("LPP10", pulp.LpMaximize)
x = pulp.LpVariable('x', lowBound=0)
y = pulp.LpVariable('y', lowBound=0)
lp += 5*x + 3*y
lp += x + y <= 7
lp += x <= 4
lp += y <= 5
lp.solve()
print("X=",x.value(), "Y=",y.value(), "Z=",pulp.value(lp.objective))
# Out:
# X= 4.0 Y= 3.0 Z= 29.0
